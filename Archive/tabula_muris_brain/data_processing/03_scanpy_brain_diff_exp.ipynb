# %%
import os 
# Get the current working directory
current_dir = os.getcwd()
print("Current working directory:", current_dir)

import pandas as pd
import scanpy as sc
import anndata as ad
from tqdm import tqdm
import matplotlib.pyplot as plt # import matplotlib to visualize our qc metrics

# magic incantation to help matplotlib work with our jupyter notebook
# %matplotlib inline 

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# Current working directory: /gpfs/commons/home/kisaev/Leaflet-analysis/tabula_muris_brain/data_processing
# scanpy==1.9.3 anndata==0.8.0 umap==0.5.3 numpy==1.23.5 scipy==1.10.1 pandas==1.5.3 scikit-learn==1.0.1 statsmodels==0.13.1 python-igraph==0.10.4 pynndescent==0.5.8

# %%
import sys
sys.path.append('../../utils')
from functions import *

# %%
# load adata object for tabula muris 
adata = sc.read_h5ad("/gpfs/commons/groups/knowles_lab/Karin/Leaflet-analysis-WD/TabulaMurisBrain/adata.h5ad")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /gpfs/commons/home/kisaev/Leaflet-analysis/tabula_muris_brain/data_processing/03_scanpy_brain_diff_exp.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Bpe2/gpfs/commons/home/kisaev/Leaflet-analysis/tabula_muris_brain/data_processing/03_scanpy_brain_diff_exp.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # load adata object for tabula muris
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpe2/gpfs/commons/home/kisaev/Leaflet-analysis/tabula_muris_brain/data_processing/03_scanpy_brain_diff_exp.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> adata = sc.read_h5ad("/gpfs/commons/groups/knowles_lab/Karin/Leaflet-analysis-WD/TabulaMurisBrain/adata.h5ad")
#
# File ~/miniconda3/envs/leafcutter-sc/lib/python3.9/site-packages/anndata/_io/h5ad.py:224, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     216         raise NotImplementedError(
#     217             "Currently only `X` and `raw/X` can be read as sparse."
#     218         )
#     220 rdasp = partial(
#     221     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     222 )
# --> 224 with h5py.File(filename, "r") as f:
#     225     d = {}
#     226     for k in f.keys():
#     227         # Backwards compat for old raw
#
# File ~/miniconda3/envs/leafcutter-sc/lib/python3.9/site-packages/h5py/_hl/files.py:533, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     525     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     526                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     527                      alignment_threshold=alignment_threshold,
#     528                      alignment_interval=alignment_interval,
#     529                      **kwds)
#     530     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     531                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                      fs_page_size=fs_page_size)
# --> 533     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     535 if isinstance(libver, tuple):
#     536     self._libver = libver
#
# File ~/miniconda3/envs/leafcutter-sc/lib/python3.9/site-packages/h5py/_hl/files.py:226, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     224     if swmr and swmr_support:
#     225         flags |= h5f.ACC_SWMR_READ
# --> 226     fid = h5f.open(name, flags, fapl=fapl)
#     227 elif mode == 'r+':
#     228     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/gpfs/commons/groups/knowles_lab/Karin/Leaflet-analysis-WD/TabulaMurisBrain/adata.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4927 × 23433
#     obs: 'cell_ontology_class', 'mouse.id', 'subtissue', 'tissue', 'cell_type', 'cell_id'
#     var: 'gene_name'

# %%
adata.obs.cell_type.unique()
# Out:
# ['Marrow_naive_B_cell', 'Marrow_monocyte', 'Marrow_regulatory_T_cell', 'Marrow_B_cell', 'Marrow_immature_T_cell', ..., 'Marrow_Slamf1-positive_multipotent_progenitor..., 'Marrow_granulocytopoietic_cell', 'Marrow_late_pro-B_cell', 'Marrow_Slamf1-negative_multipotent_progenitor..., 'Marrow_hematopoietic_precursor_cell']
# Length: 22
# Categories (22, object): ['Marrow_B_cell', 'Marrow_Slamf1-negative_multipotent_progenitor..., 'Marrow_Slamf1-positive_multipotent_progenitor..., 'Marrow_basophil', ..., 'Marrow_naive_B_cell', 'Marrow_pre-natural_killer_cell', 'Marrow_precursor_B_cell', 'Marrow_regulatory_T_cell']

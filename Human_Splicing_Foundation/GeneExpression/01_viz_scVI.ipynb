# %%
import scanpy as sc
import anndata as ad

# Load the AnnData
ge_adata = ad.read_h5ad("/gpfs/commons/groups/knowles_lab/Karin/Leaflet-analysis-WD/HUMAN_SPLICING_FOUNDATION/MODEL_INPUT/042025/ge_adata_matched_with_linearSCVI_2025-04-28.h5ad")

# %%
sc.pl.umap(
    ge_adata,
    color=["dataset", "tissue", "broad_cell_type", "leiden_scVI"],
    ncols=1
)

# %%
# Step 1: Subset ge_adata to only Microglia_Macrophage
microglia_adata = ge_adata[ge_adata.obs['broad_cell_type'] == 'Microglia_Macrophage']

# Step 2: Plot UMAP colored by 'dataset'
sc.pl.umap(
    microglia_adata,
    color=["dataset", "tissue"],
    ncols=1
)
